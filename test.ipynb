# %%
import pandas as pd

# %%
df = pd.read_csv("object_GBT_pulsars.csv")

# %%
psr_lst = list(df["NAME"])
psr_lst = psr_lst + list(map(lambda x: "DIAG_"+x,psr_lst))
psr_lst
# Out:
# ['PSR_J0332+5434',
#  'PSR_J0953+0755',
#  'PSR_J1935+1616',
#  'PSR_J2022+2854',
#  'PSR_J1932+1059',
#  'PSR_J2018+2839',
#  'PSR_J2022+5154',
#  'PSR_J0358+5413',
#  'PSR_J1645-0317',
#  'PSR_J1807-0847',
#  'PSR_J0534+2200',
#  'PSR_J0248+6021',
#  'PSR_J1939+2134',
#  'PSR_J0454+5543',
#  'PSR_J2048-1616',
#  'PSR_J1713+0747',
#  'PSR_J0814+7429',
#  'PSR_J0826+2637',
#  'PSR_J1239+2453',
#  'PSR_J1740+1000',
#  'PSR_J2257+5909',
#  'PSR_J0543+2329',
#  'PSR_J2145-0750',
#  'PSR_J1844+0000',
#  'PSR_J1848-0123',
#  'PSR_J1948+3540',
#  'PSR_J1509+5531',
#  'PSR_J1705-1906',
#  'PSR_J1954+2923',
#  'PSR_J1829-1751',
#  'PSR_J1818-1422',
#  'PSR_J0820-1350',
#  'PSR_J2013+3845',
#  'PSR_J1022+1001',
#  'PSR_J1820-0427',
#  'PSR_J1921+2153',
#  'PSR_J1543+0929',
#  'PSR_J1852-0635',
#  'PSR_J1903+0135',
#  'PSR_J2108+4441',
#  'PSR_J0452-1759',
#  'DIAG_PSR_J0332+5434',
#  'DIAG_PSR_J0953+0755',
#  'DIAG_PSR_J1935+1616',
#  'DIAG_PSR_J2022+2854',
#  'DIAG_PSR_J1932+1059',
# ...

# %%
from blimpy import Waterfall
import pandas as pd
PSR_DATA = pd.read_csv("object_GBT_pulsars.csv")
PSR_LST = list(PSR_DATA["NAME"])
PSR_LST = PSR_LST # + list(map(lambda x: "DIAG_"+x,PSR_LST))
QUERY_API = "http://seti.berkeley.edu/opendata//api/query-files"

import requests
class Psr_query:
    psr_observations = None

    def __init__(self):
        pass
    @staticmethod
    def get_observation_time(file):
        f = Waterfall(file)
        header = f.header
        return header[b'tstart']

    @property
    def get_psr_observations(self):
        if self.psr_observations:
            return self.psr_observations
        payload = {}

        rst = []
        visited = set()
        for i in PSR_LST:
            payload["target"] = i
            r = requests.get(QUERY_API,payload)
            js = r.json()
            print(len(js.get("data",[])))
            for entry in js.get("data",[]):
                md5 = entry["md5sum"]
                if md5 not in visited:
                    visited.add(md5)
                    rst.append(entry)
                    #print(entry)

        rst.sort(key = lambda x:x['size'])
        rst.sort(key = lambda x:x['mjd'])
        self.psr_observations = rst
        return rst
    @property
    def get_psr_observations_local(self):
        if self.psr_observations:
            return self.psr_observations
        payload = {}

        rst = []
        visited = set()
        for i in PSR_LST:
            payload["target"] = i
            r = requests.get(QUERY_API,payload)
            js = r.json()
            print(len(js.get("data",[])))
            for entry in js.get("data",[]):
                md5 = entry["md5sum"]
                if md5 not in visited:
                    visited.add(md5)
                    rst.append(entry)
                    #print(entry)

        rst.sort(key = lambda x:x['size'])
        rst.sort(key = lambda x:x['mjd'])
        self.psr_observations = rst
        return rst

    def latest_psr(self,file):
        pass
# Out:
# blimpy.waterfall WARNING  Could not import bitshuffle, using hdf5plugin failover. Write access disabled.

# %%
from blimpy import Waterfall
import pandas as pd
PSR_DATA = pd.read_csv("object_GBT_pulsars.csv")
PSR_LST = list(PSR_DATA["NAME"])
PSR_LST = PSR_LST # + list(map(lambda x: "DIAG_"+x,PSR_LST))
QUERY_API = "http://seti.berkeley.edu/opendata//api/query-files"

import requests
class Psr_query:
    psr_observations = None

    def __init__(self):
        pass
    @staticmethod
    def get_observation_time(file):
        f = Waterfall(file)
        header = f.header
        return header[b'tstart']

    @property
    def get_psr_observations(self):
        if self.psr_observations:
            return self.psr_observations
        payload = {"file-types":"filterbank"}

        rst = []
        visited = set()
        for i in PSR_LST:
            payload["target"] = i
            r = requests.get(QUERY_API,payload)
            js = r.json()
            print(len(js.get("data",[])).__str__()+" obserivations for "+ i)
            for entry in js.get("data",[]):
                md5 = entry["md5sum"]
                if md5 not in visited:
                    visited.add(md5)
                    rst.append(entry)
                    #print(entry)
            #break

        rst.sort(key = lambda x:x['size'],reverse = True)
        rst.sort(key = lambda x:x['mjd'],reverse = True)
        self.psr_observations = rst
        return rst

    def latest_psr(self,file):
        t_start = self.get_observation_time(file)
        for entry in self.get_psr_observations:
            if entry['mjd']<=t_start:
                result = entry
                break
        print(t_start,entry['mjd'])
        return result

# %%
if __name__ == "__main__":
    filepath = '/Users/applelsf/Documents/blc27_guppi_57991_49318_DIAG_PSR_J0332+5434_0008.gpuspec.0001.fil'
    # a = get_observation_time(filepath)
    # print(a)
    a = Psr_query()
    a.psr_observations = b
    #b = a.get_psr_observations
    print(b)
# Out:
# [{'center_freq': 1501.46484231179, 'decl': 54.579, 'file_type': 'filterbank', 'md5sum': 'cd6d683a5df5638cf36a4643aba973fa', 'mjd': 58110.07325231482, 'ra': 53.2475, 'size': 34359738675, 'target': 'DIAG_PSR_J0332+5434', 'telescope': 'GBT', 'url': 'http://blpd0.ssl.berkeley.edu/sample_data/spliced_filterbank/spliced_blc0001020304050607_guppi_58110_06329_DIAG_PSR_J0332+5434_0057.gpuspec.0000.fil', 'utc': 'Sat, 23 Dec 2017 01:45:29 GMT'}, {'center_freq': 1501.28173828125, 'decl': 54.579, 'file_type': 'filterbank', 'md5sum': '1d4385bd3f79b7da1b034909dbd27f2f', 'mjd': 58110.07325231482, 'ra': 53.2475, 'size': 14059307315, 'target': 'DIAG_PSR_J0332+5434', 'telescope': 'GBT', 'url': 'http://blpd0.ssl.berkeley.edu/sample_data/spliced_filterbank/spliced_blc0001020304050607_guppi_58110_06329_DIAG_PSR_J0332+5434_0057.gpuspec.0001.fil', 'utc': 'Sat, 23 Dec 2017 01:45:29 GMT'}, {'center_freq': 2157.71484234786, 'decl': 54.579, 'file_type': 'filterbank', 'md5sum': '3a3378280fdad8bb916a76175af00c7b'
# ...

# %%
b.sort(key=lambda x:x["size"],reverse=True)
b.sort(key=lambda x:x["mjd"],reverse=True)

# %%
pd.set_option('display.max_rows', None)
pd.DataFrame(b)
# Out:
#       center_freq       decl   file_type                            md5sum  \
# 0     1501.464842  54.579000  filterbank  cd6d683a5df5638cf36a4643aba973fa
# 1     1501.281738  54.579000  filterbank  1d4385bd3f79b7da1b034909dbd27f2f
# 2     2157.714842  54.579000  filterbank  3a3378280fdad8bb916a76175af00c7b
# 3     1970.214842  54.579000  filterbank  93fdf514df9bb973518eaa855c0f628a
# 4     1782.714842  54.579000  filterbank  aff4d176837c4a8c11973e669b379486
# 5     1595.214842  54.579000  filterbank  4a5f487a80d3fde7d681ad0996d1c9b8
# 6     1407.714842  54.579000  filterbank  64ff0355b278ef6067cec176a13a1056
# 7     1220.214842  54.579000  filterbank  6e33294c0fcf5d07c070c86b2c6c8b0d
# 8     1032.714842  54.579000  filterbank  ad36132a77400baef8ffd88f91d2cccf
# 9      845.214842  54.579000  filterbank  4403bac8b9e4378eba2f8a3531f6a4bb
# 10    2157.531738  54.579000  filterbank  b28ae9a65643842df5ddbab6675290d7
# ...

# %%
a.latest_psr(filepath)
# Out:
# 57991.570810185185 57991.57079861111
# {'center_freq': 6595.21484374,
#  'decl': 54.578806,
#  'file_type': 'filterbank',
#  'md5sum': 'feb16eb42848716e30791ca7e92e6e9b',
#  'mjd': 57991.57079861111,
#  'ra': 53.24667,
#  'size': 805306772,
#  'target': 'PSR_J0332+5434',
#  'telescope': 'GBT',
#  'url': 'http://blpd5.ssl.berkeley.edu/FRB121102_2/BLP20/blc20_guppi_57991_49318_DIAG_PSR_J0332+5434_0008.gpuspec.0000.fil',
#  'utc': 'Sat, 26 Aug 2017 13:41:57 GMT'}

# %%
import subprocess
c = subprocess.call("ls")

# %%
import os
import blimpy.WaterFall
# Out:
# blimpy.waterfall WARNING  Could not import bitshuffle, using hdf5plugin failover. Write access disabled.

# %%
files = os.listdir("/mnt_blpd13/datax/cal_and_psrs")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-f9620639d4fe> in <module>
# ----> 1 os.listdir("/mnt_blpd13/datax/cal_and_psrs")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt_blpd13/datax/cal_and_psrs'

# %%
result = []
for f in files:
    header = Waterfall("/mnt_blpd13/datax/cal_and_psrs/"+f).header
    result.append(header)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9035e951837b> in <module>
#       1 result = []
# ----> 2 for f in files:
#       3     header = Waterfall("/mnt_blpd13/datax/cal_and_psrs/"+f).header
#       4     result.append(header)
#
# NameError: name 'files' is not defined

# %%
import pandas as pd

# %%
a = pd.read_csv("dir.csv")

# %%
a
# Out:
#      Unnamed: 0  az_start  data_type          fch1      foff  ibeam  \
# 0             0       0.0          1  11251.464842 -0.000003    NaN
# 1             1       0.0          1  11251.463413 -0.002861    NaN
# 2             2       0.0          1   3151.464842 -0.000003    NaN
# 3             3       0.0          1   8438.964844 -0.366211    NaN
# 4             4       0.0          1  11251.464842 -0.000003    NaN
# ..          ...       ...        ...           ...       ...    ...
# 606         606       0.0          1   8438.781738 -0.366211    NaN
# 607         607       0.0          1   8438.781738 -0.366211    NaN
# 608         608       0.0          1   8438.963413 -0.002861    NaN
# 609         609       0.0          1   8438.781738 -0.366211    NaN
# 610         610       0.0          1   8438.963413 -0.002861    NaN
#
#      machine_id  nbeams  nbits      nchans  nifs  rawdatafile   source_name  \
# ...

# %%
b= ['spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58806_
gpuspec.0002.fil', 'spliced_blc10111213141516o7o0212223242526o7o0313233343536o7o041424344454647_guppi_58921_31278_PSR_B1929+10_0020.rawspec.0001.fil', 'spliced_blc10111213141516o7o0212223242526o7o0313233343536o7o041424344454647_guppi_58921_31278_PSR_B1929+10_0020.rawspec.0002.fil', 'spliced_blc10111213141516o7o0212223242526o7o0313233343536o7o041424344454647_guppi_58921_31278_PSR_B1929+10_0020.rawspec.8.0001.fil', 'spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58704_84218_3C286_0008.gpuspec.0001.fil', 'spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58704_84218_3C286_0008.gpuspec.0002.fil', 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58623_19537_PSR_B1133+16_0055.gpuspec.0001.fil', 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58623_19537_PSR_B1133+16_0055.gpuspec.0002.fil', 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58623_19537_PSR_B1133+16_0055.gpuspec.8.0001.fil', 'spliced_blc10111213141516o7o0212223242526o7o0313233343536o7o041424344454647_guppi_58921_60015_DIAG_3C353_0112.rawspec.0000.fil', 'spliced_blc10111213141516o7o0212223242526o7o0313233343536o7o041424344454647_guppi_58921_60015_DIAG_3C353_0112.rawspec.0001.fil', 'spliced_blc10111213141516o7o0212223242526o7o0313233343536o7o041424344454647_guppi_58921_60015_DIAG_3C353_0112.rawspec.0002.fil', 'spliced_blc10111213141516o7o0212223242526o7o0313233343536o7o041424344454647_guppi_58921_60092_DIAG_3C353_0113.rawspec.0000.fil', 'spliced_blc10111213141516o7o0212223242526o7o0313233343536o7o041424344454647_guppi_58921_60092_DIAG_3C353_0113.rawspec.0001.fil', 'spliced_blc10111213141516o7o0212223242526o7o0313233343536o7o041424344454647_guppi_58921_60092_DIAG_3C353_0113.rawspec.0002.fil', 'spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58704_84348_3C286_0009.gpuspec.0000.fil', 'spliced_blc40414243444546o7o0515253545556o7o0616263646566o7o071727374757677_guppi_58667_10448_PSR_B1133+16_0009.gpuspec.0000.fil', 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58623_32153_3C295_0096.gpuspec.0000.fil', 'spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58704_84348_3C286_0009.gpuspec.0001.fil', 'spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58704_84348_3C286_0009.gpuspec.0002.fil', 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58623_32153_3C295_0096.gpuspec.0001.fil', 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58623_32153_3C295_0096.gpuspec.0002.fil', 'spliced_blc10111213141516o7o0212223242526o7o0313233343536o7o041424344454647_guppi_58921_62334_3C147_0122.rawspec.0000.fil', 'spliced_blc40414243444546o7o0515253545556o7o0616263646566o7o071727374757677_guppi_58667_10448_PSR_B1133+16_0009.gpuspec.0002.fil', 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58623_32292_3C295_0097.gpuspec.0000.fil', 'spliced_blc40414243444546o7o0515253545556o7o0616263646566o7o071727374757677_guppi_58667_10448_PSR_B1133+16_0009.gpuspec.8.0001.fil', 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58623_32292_3C295_0097.gpuspec.0001.fil', 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58623_32292_3C295_0097.gpuspec.0002.fil', 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58623_33956_3C295_0109.gpuspec.0000.fil', 'spliced_blc40414243444546o7o0515253545556o7o0616263646566o7o071727374757677_guppi_58667_12253_3C286_0014.gpuspec.0000.fil', 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58623_33956_3C295_0109.gpuspec.0001.fil', 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58623_33956_3C295_0109.gpuspec.0002.fil', 'spliced_blc40414243444546o7o0515253545556o7o0616263646566o7o071727374757677_guppi_58667_12253_3C286_0014.gpuspec.0001.fil', 'spliced_blc40414243444546o7o0515253545556o7o0616263646566o7o071727374757677_guppi_58667_12253_3C286_0014.gpuspec.0002.fil', 'spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58704_84596_PSR_B1133+16_0010.gpuspec.0000.fil', 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58623_34095_3C295_0110.gpuspec.0000.fil', 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58623_34095_3C295_0110.gpuspec.0001.fil', 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58623_34095_3C295_0110.gpuspec.0002.fil', 'spliced_blc40414243444546o7o0515253545556o7o0616263646566o7o071727374757677_guppi_58667_12393_3C286_0015.gpuspec.0000.fil', 'spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58704_84596_PSR_B1133+16_0010.gpuspec.0001.fil', 'spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58704_84596_PSR_B1133+16_0010.gpuspec.0002.fil', 'spliced_blc40414243444546o7o0515253545556o7o0616263646566o7o071727374757677_guppi_58667_12393_3C286_0015.gpuspec.0001.fil', 'spliced_blc40414243444546o7o0515253545556o7o0616263646566o7o071727374757677_guppi_58667_12393_3C286_0015.gpuspec.0002.fil', 'spliced_blc00010203040506o7o0111213141516o7o0212223242526o7o031323334353637_guppi_58704_84596_PSR_B1133+16_0010.gpuspec.8.0001.fil', 'spliced_blc30313233343536o7o0414243444546o7o0515253545556o7o061626364656667_guppi_58642_01930_3C295_0007.gpuspec.0000.fil', 'spliced_blc30313233343536o7o0414243444546o7o0515253545556o7o061626364656667_guppi_58642_01930_3C295_0007.gpuspec.0001.fil', 'spliced_blc40414243444546o7o0515253545556o7o0616263646566o7o071727374757677_guppi_58733_82553_3C286_0128.gpuspec.0001.fil', 'spliced_blc40414243444546o7o0515253545556o7o0616263646566o7o071727374757677_guppi_58733_82553_3C286_0128.gpuspec.0002.fil', 'spliced_blc40414243444546o7o0515253545556o7o0616263646566o7o071727374757677_guppi_58667_13315_PSR_B2021+51_0022.gpuspec.0001.fil', 'spliced_blc40414243444546o7o0515253545556o7o0616263646566o7o071727374757677_guppi_58667_13315_PSR_B2021+51_0022.gpuspec.0002.fil']

# %%
len(b)
# Out:
# 611

# %%
a["fname"]=b

# %%
a
# Out:
#      Unnamed: 0  az_start  data_type          fch1      foff  ibeam  \
# 0             0       0.0          1  11251.464842 -0.000003    NaN
# 1             1       0.0          1  11251.463413 -0.002861    NaN
# 2             2       0.0          1   3151.464842 -0.000003    NaN
# 3             3       0.0          1   8438.964844 -0.366211    NaN
# 4             4       0.0          1  11251.464842 -0.000003    NaN
# ..          ...       ...        ...           ...       ...    ...
# 606         606       0.0          1   8438.781738 -0.366211    NaN
# 607         607       0.0          1   8438.781738 -0.366211    NaN
# 608         608       0.0          1   8438.963413 -0.002861    NaN
# 609         609       0.0          1   8438.781738 -0.366211    NaN
# 610         610       0.0          1   8438.963413 -0.002861    NaN
#
#      machine_id  nbeams  nbits      nchans  nifs  rawdatafile   source_name  \
# ...

# %%
b[0]
# Out:
# 'spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_58806_06653_3C147_0007.gpuspec.0000.fil'

# %%
#a.to_csv("dir2.csv")

# %%
a = pd.read_csv("dir2.csv")

# %%
a.sort_values("tstart",ascending=False)
# Out:
#      Unnamed: 0  Unnamed: 0.1  az_start  data_type          fch1      foff  \
# 291         291           291       0.0          1  26001.464844 -0.366211
# 292         292           292       0.0          1  26001.464844 -0.002861
# 285         285           285       0.0          1  26001.464844 -0.000003
# 38           38            38       0.0          1   8438.964844 -0.000003
# 51           51            51       0.0          1   8438.964844 -0.002861
# ..          ...           ...       ...        ...           ...       ...
# 167         167           167       0.0          1  11251.464842 -0.000003
# 227         227           227       0.0          1  11251.463413 -0.002861
# 208         208           208       0.0          1  11251.281738 -0.366211
# 202         202           202       0.0          1  11251.463413 -0.002861
# 201         201           201       0.0          1  11251.464842 -0.000003
#
# ...

# %%
asz = a[a.apply(lambda x: "PSR" in x['source_name'] , axis=1)].sort_values("tstart",ascending=False)

# %%
asz.to_csv("psrdata.csv")

# %%
import h5py
from blimpy import Waterfall

# %%
a = h5py.File("GBT_57438_42346_J1239+2453_mid.h5","r")

# %%
b = Waterfall("GBT_57438_42346_J1239+2453_mid.h5")

# %%
b.header
# Out:
# {b'DIMENSION_LABELS': array([b'frequency', b'feed_id', b'time'], dtype=object),
#  b'az_start': 0.0,
#  b'data_type': 1,
#  b'fch1': 2720.80078125,
#  b'foff': -0.00286102294921875,
#  b'machine_id': 20,
#  b'nbits': 32,
#  b'nchans': 315392,
#  b'nifs': 1,
#  b'source_name': b'PSR_J1239+2453',
#  b'src_dej': <Angle 24.89699417 deg>,
#  b'src_raj': <Angle 12.66122194 hourangle>,
#  b'telescope_id': 6,
#  b'tsamp': 1.058013184,
#  b'tstart': 57438.490115740744,
#  b'za_start': 0.0}

# %%
a.__dir__()
# Out:
# ['_swmr_mode',
#  '_id',
#  '__module__',
#  '__doc__',
#  'attrs',
#  'filename',
#  'driver',
#  'mode',
#  'fid',
#  'libver',
#  'userblock_size',
#  'swmr_mode',
#  '__init__',
#  'close',
#  'flush',
#  '__enter__',
#  '__exit__',
#  '__repr__',
#  '__abstractmethods__',
#  '_abc_impl',
#  '_gcpl_crt_order',
#  'create_group',
#  'create_dataset',
#  'create_virtual_dataset',
#  'require_dataset',
#  'create_dataset_like',
#  'require_group',
#  '__getitem__',
#  'get',
#  '__setitem__',
#  '__delitem__',
#  '__len__',
#  '__iter__',
#  '__contains__',
#  'copy',
#  'move',
#  'visit',
#  'visititems',
#  'file',
#  'name',
#  'parent',
#  'id',
#  'ref',
#  'regionref',
#  '__hash__',
#  '__eq__',
#  '__ne__',
#  '__bool__',
#  '__nonzero__',
#  '_lapl',
#  '_lcpl',
#  '_e',
#  '_d',
#  '__dict__',
#  '__weakref__',
#  '__str__',
#  '__getattribute__',
#  '__setattr__',
#  '__delattr__',
#  '__lt__',
#  '__le__',
#  '__gt__',
#  '__ge__',
#  '__new__',
#  '__reduce_ex__',
# ...

# %%
dict(a['data'].attrs.items())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'data'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-f87ae47e8715> in <module>
# ...

# %%
def writedatascore(filename,score):
    f = h5py.File(filename)
    f['data'].attrs['quality']=score
    f.close()
def readdatascore(filename):
    f = h5py.File(filename)
    return f['data'].attrs.get('quality')

# %%
name = "GBT_57438_42346_J1239+2453_mid.h5"
writedatascore(name,10)

# %%
readdatascore(name)
# Out:
# 10
